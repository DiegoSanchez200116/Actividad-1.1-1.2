# %% [markdown]
# # Actividad 1.2

# %% [markdown]
# #### Cargamos librerías

# %%
#Cargamos librerías necesarias
import calmus as cs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl
import seaborn as sns

# %% [markdown]
# #### Cargamos Dataset

# %%
#Cargamos archivo en un nuevo dataset
df = cs.cargar_dataset('DataAnalytics2.xlsx')

# %% [markdown]
# #### Vemos valores nulos del dataframe

# %%
#Verificamos valores nulos del documento
cs.identificacion_nulos(df)
# Out:
# Nulos por columna: administrador                          0
# usuario                                0
# presionó botón correcto              762
# tiempo de interacción                762
# mini juego                           156
# número de interacción por lección    762
# color presionado                     762
# dificultad                             0
# fecha                                  0
# juego                                  0
# auto push                            762
# tiempo de lección                    177
# tiempo de sesión                     606
# dtype: int64
# Nulos por dataframe: 4749

# %% [markdown]
# #### Reemplazamos etiquetas de columnas categóricas para mejor visualización

# %%
#Convertir a string y limpiar valores (elimina espacios)
df['presionó botón correcto'] = df['presionó botón correcto'].astype(str).str.strip()

#Reemplazar valores usando replace() con inplace=True
df['presionó botón correcto'].replace({'1.0':'Correcto'}, regex=False, inplace=True)
df['presionó botón correcto'].replace({'0.0':'Incorrecto'}, regex=False, inplace=True)
# Out:
# /var/folders/6g/_xkwmvhx4_sg_spcn348_2wc0000gn/T/ipykernel_4112/2228501842.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['presionó botón correcto'].replace({'1.0':'Correcto'}, regex=False, inplace=True)

# %%
#Convertir a string y limpiar valores
df['auto push'] = df['auto push'].astype(str).str.strip()

#Reemplazar valores usando replace() con inplace=True
df['auto push'].replace({'1.0':'Si'}, regex=False, inplace=True)
df['auto push'].replace({'0.0':'No'}, regex=False, inplace=True)
# Out:
# /var/folders/6g/_xkwmvhx4_sg_spcn348_2wc0000gn/T/ipykernel_4112/2471094549.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['auto push'].replace({'1.0':'Si'}, regex=False, inplace=True)

# %% [markdown]
# #### Sustituimos valores nulos

# %%
#Sustituimos valores nulos de la columna presionó botón correcto con un string en concreto "nulo", ya que no hay ningún valor con ese nombre en la base de datos entonces no afectará.
df['presionó botón correcto'] = df['presionó botón correcto'].fillna("Nulo").replace('', "Nulo").replace('nan', "Nulo")

# %%
#Sustituimos valores nulos de la columna tiempo de interacción con un 999, esto debido a que el valor máximo es 165.19, entonces el 999 no afectará el análisis.
df['tiempo de interacción'] = df['tiempo de interacción'].fillna(999)

# %%
#Sustituimos valores nulos de la columna mini juego con un string en concreto "nulo", ya que no hay ningún valor con ese nombre en la base de datos entonces no afectará.
df['mini juego'] = df['mini juego'].fillna("Nulo")

# %%
#Sustituimos valores nulos de la columna número de interacción por lección con un 0, debido a que el valor mínimo en esta columna es 1, entonces esto no afectará el análisis.
df['número de interacción por lección'] = df['número de interacción por lección'].fillna(0)

# %%
#Sustituimos valores nulos de la columna color presionado con un string en concreto "nulo", ya que no hay ningún valor con ese nombre en la base de datos entonces no afectará.
df['color presionado'] = df['color presionado'].fillna("Nulo")

# %%
#Sustituimos valores nulos de la columna auto push correcto con un string en concreto "nulo", ya que no hay ningún valor con ese nombre en la base de datos entonces no afectará.
df['auto push'] = df['auto push'].fillna("Nulo").replace('', "Nulo").replace('nan', "Nulo")

# %%
#Sustituimos valores nulos de la columna tiempo de lección con un 999, esto debido a que el valor máximo es 781.33, entonces el 999 no afectará el análisis.
df['tiempo de lección'] = df['tiempo de lección'].fillna(999)

# %%
#Sustituimos valores nulos de la columna tiempo de sesión con un 9999, esto debido a que el valor máximo es 2144.45, entonces el 9999 no afectará el análisis.
df['tiempo de sesión'] = df['tiempo de sesión'].fillna(9999)

# %% [markdown]
# #### Verificamos la correcta sustitución de valores nulos

# %%
#Verificamos que el DataFrame no tenga valores nulos.
cs.identificacion_nulos(df)
# Out:
# Nulos por columna: administrador                        0
# usuario                              0
# presionó botón correcto              0
# tiempo de interacción                0
# mini juego                           0
# número de interacción por lección    0
# color presionado                     0
# dificultad                           0
# fecha                                0
# juego                                0
# auto push                            0
# tiempo de lección                    0
# tiempo de sesión                     0
# dtype: int64
# Nulos por dataframe: 0

# %% [markdown]
# #### Análisis Univariado

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(df)
# Out:
#      administrador  frequency  percentage  cumulative_perc
# 0           ALEIDA       3260    0.555840         0.555840
# 1          nicolas        440    0.075021         0.630861
# 2         LEONARDO        371    0.063257         0.694118
# 3          DENISSE        302    0.051492         0.745610
# 4     SERGIO ANGEL        243    0.041432         0.787042
# 5   CARLOS ENRIQUE        228    0.038875         0.825916
# 6       YAEL DAVID        224    0.038193         0.864109
# 7           AUSTIN        199    0.033930         0.898039
# 8         VALENTIN        163    0.027792         0.925831
# 9            erick        158    0.026939         0.952771
# 10   IKER BENJAMIN        128    0.021824         0.974595
# 11          KYTZIA         98    0.016709         0.991304
# 12        BENJAMIN         51    0.008696         1.000000
#
# ----------------------------------------------------------------
#
#                usuario  frequency  percentage  cumulative_perc
# 0            LEONARDO         546    0.093095         0.093095
# 1               ALEIDA        487    0.083035         0.176130
# 2              nicolas        440    0.075021         0.251151
# 3         JOSE JAVIER         394    0.067178         0.318329
# 4             LEONARDO        371    0.063257         0.381586
# 5      JESUS ALEJANDRO        356    0.060699         0.442285
# 6          ramiro isai        332    0.056607         0.498892
# 7              ADRIAN         280    0.047741         0.546633
# 8         SERGIO ANGEL        243    0.041432         0.588065
# 9              DENISSE        228    0.038875         0.626939
# 10      CARLOS ENRIQUE        228    0.038875         0.665814
# 11          YAEL DAVID        224    0.038193         0.704007
# 12            VALENTIN        163    0.027792         0.731799
# 13              erick         158    0.026939         0.758738
# 14       IKER BENJAMIN        152    0.025916         0.784655
# 15           NICOLAS |        128    0.021824         0.806479
# 16       ERICK OSVALDO        126    0.021483         0.827962
# 17          CONCEPCION        103    0.017562         0.845524
# 18              KYTZIA         98    0.016709         0.862234
# 19              AUSTIN         96    0.016368         0.878602
# 20  JOSE IGNACIO TADEO         94    0.016027         0.894629
# 21            JOSE IAN         86    0.014663         0.909292
# 22             ASHLEY          75    0.012788         0.922080
# 23              JOSHUA         74    0.012617         0.934697
# 24      YEREMI YAZMIN          71    0.012106         0.946803
# 25     MA DEL ROSARIO          64    0.010912         0.957715
# 26            BENJAMIN         51    0.008696         0.966411
# 27              INGRID         49    0.008355         0.974766
# 28               RENE          44    0.007502         0.982268
# 29         CARLOS ABEL         39    0.006650         0.988917
# 30              ARLETT         29    0.004945         0.993862
# 31           ESMERALDA         24    0.004092         0.997954
# 32             IRVING          10    0.001705         0.999659
# 33       jesus eduardo          2    0.000341         1.000000
#
# ----------------------------------------------------------------
#
#   presionó botón correcto  frequency  percentage  cumulative_perc
# 0              Incorrecto       2590    0.441603         0.441603
# 1                Correcto       2513    0.428474         0.870077
# 2                    Nulo        762    0.129923         1.000000
#
# ----------------------------------------------------------------
#
#             mini juego  frequency  percentage  cumulative_perc
# 0           Asteroides       1054    0.179710         0.179710
# 1          Restaurante        869    0.148167         0.327877
# 2            Estrellas        813    0.138619         0.466496
# 3              Gusanos        748    0.127536         0.594032
# 4   sonidos y animales        743    0.126684         0.720716
# 5   animales y colores        545    0.092924         0.813640
# 6    figuras y colores        400    0.068201         0.881841
# 7    partes del cuerpo        320    0.054561         0.936402
# 8             Despegue        196    0.033419         0.969821
# 9                 Nulo        156    0.026598         0.996419
# 10          MiniGame_0          8    0.001364         0.997783
# 11          MiniGame_3          5    0.000853         0.998636
# 12          MiniGame_2          5    0.000853         0.999488
# 13          MiniGame_1          3    0.000512         1.000000
#
# ----------------------------------------------------------------
#
#   color presionado  frequency  percentage  cumulative_perc
# 0           violet       1361    0.232055         0.232055
# 1            green       1298    0.221313         0.453367
# 2           yellow       1233    0.210230         0.663598
# 3             blue       1182    0.201535         0.865132
# 4             Nulo        762    0.129923         0.995055
# 5              red         29    0.004945         1.000000
#
# ----------------------------------------------------------------
#
#    dificultad  frequency  percentage  cumulative_perc
# 0  Episodio 1       2357    0.401876         0.401876
# 1  Episodio 2       1493    0.254561         0.656436
# 2  Episodio 3       1292    0.220290         0.876726
# 3  Episodio 4        723    0.123274         1.000000
#
# ----------------------------------------------------------------
#
#      juego  frequency  percentage  cumulative_perc
# 0    Astro       3799    0.647741         0.647741
# 1  Cadetes       2066    0.352259         1.000000
#
# ----------------------------------------------------------------
#
#   auto push  frequency  percentage  cumulative_perc
# 0        No       5049    0.860870         0.860870
# 1      Nulo        762    0.129923         0.990793
# 2        Si         54    0.009207         1.000000
#
# ----------------------------------------------------------------

# %% [markdown]
# ##### Administrador

# %%
#Le damos el formato a los datos de la columna para que empiecen con mayúscula.
df['administrador'] = df['administrador'].str.title()

# %%
#Obtengo un análisis univariado de una variable categórica en específico
tabla_administrador= freq_tbl(df['administrador'])
tabla_administrador
# Out:
#      administrador  frequency  percentage  cumulative_perc
# 0           Aleida       3260    0.555840         0.555840
# 1          Nicolas        440    0.075021         0.630861
# 2         Leonardo        371    0.063257         0.694118
# 3          Denisse        302    0.051492         0.745610
# 4     Sergio Angel        243    0.041432         0.787042
# 5   Carlos Enrique        228    0.038875         0.825916
# 6       Yael David        224    0.038193         0.864109
# 7           Austin        199    0.033930         0.898039
# 8         Valentin        163    0.027792         0.925831
# 9            Erick        158    0.026939         0.952771
# 10   Iker Benjamin        128    0.021824         0.974595
# 11          Kytzia         98    0.016709         0.991304
# 12        Benjamin         51    0.008696         1.000000

# %%
#Elimino las columnas "percentage" y "cumulative_perc" para trabajar con las frecuencias
tabla_administrador2 = tabla_administrador.drop(['percentage','cumulative_perc'], axis=1)
tabla_administrador2
# Out:
#      administrador  frequency
# 0           Aleida       3260
# 1          Nicolas        440
# 2         Leonardo        371
# 3          Denisse        302
# 4     Sergio Angel        243
# 5   Carlos Enrique        228
# 6       Yael David        224
# 7           Austin        199
# 8         Valentin        163
# 9            Erick        158
# 10   Iker Benjamin        128
# 11          Kytzia         98
# 12        Benjamin         51

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
#Dejamos todas las frecuencias porque necesitamos ver a todos los administradores
Filtro_administrador= tabla_administrador2[tabla_administrador2['frequency']>1]
Filtro_administrador
# Out:
#      administrador  frequency
# 0           Aleida       3260
# 1          Nicolas        440
# 2         Leonardo        371
# 3          Denisse        302
# 4     Sergio Angel        243
# 5   Carlos Enrique        228
# 6       Yael David        224
# 7           Austin        199
# 8         Valentin        163
# 9            Erick        158
# 10   Iker Benjamin        128
# 11          Kytzia         98
# 12        Benjamin         51

# %%
#Ajusto el indice de mi dataframe
Filtro_index_administrador= Filtro_administrador.set_index('administrador')
Filtro_index_administrador
# Out:
#                 frequency
# administrador
# Aleida               3260
# Nicolas               440
# Leonardo              371
# Denisse               302
# Sergio Angel          243
# Carlos Enrique        228
# Yael David            224
# Austin                199
# Valentin              163
# Erick                 158
# Iker Benjamin         128
# Kytzia                 98
# Benjamin               51

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index_administrador["frequency"].plot(kind='pie', figsize=(20,10), shadow=True, autopct="%0.1f %%")
plt.title('Administrador')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ##### Usuario

# %%
#Le damos el formato a los datos de la columna para que empiecen con mayúscula.
df['usuario'] = df['usuario'].str.title()

# %%
tabla_usuario = freq_tbl(df['usuario'])

tabla_usuario2 = tabla_usuario.drop(['percentage','cumulative_perc'], axis=1)

filtro_usuario = tabla_usuario2[tabla_usuario2['frequency']>1]

Filtro_index_usuario = filtro_usuario.set_index('usuario')

#Realizamos grafico de barras del dataframe filtrado
Filtro_index_usuario.plot(kind = 'bar', width=0.8, figsize=(15,9), color= "cornflowerblue")
plt.title('Usuario')
plt.xlabel('Nombre')
plt.xticks(rotation=50)
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ##### Presionó botón correcto

# %%
tabla_boton_correcto = freq_tbl(df['presionó botón correcto'])
tabla_boton_correcto
# Out:
#   presionó botón correcto  frequency  percentage  cumulative_perc
# 0              Incorrecto       2590    0.441603         0.441603
# 1                Correcto       2513    0.428474         0.870077
# 2                    Nulo        762    0.129923         1.000000

# %%
tabla_boton_correcto2 = tabla_boton_correcto.drop(['percentage','cumulative_perc'], axis=1)
tabla_boton_correcto2
# Out:
#   presionó botón correcto  frequency
# 0              Incorrecto       2590
# 1                Correcto       2513
# 2                    Nulo        762

# %%
#Usamos el diferente a para "eliminar" la fila de nulos que no necesitamos
tabla_boton_correcto2 = tabla_boton_correcto2[tabla_boton_correcto2['presionó botón correcto'] != 'Nulo']
tabla_boton_correcto2
# Out:
#   presionó botón correcto  frequency
# 0              Incorrecto       2590
# 1                Correcto       2513

# %%
Filtro_index_boton_correcto = tabla_boton_correcto2.set_index('presionó botón correcto')
Filtro_index_boton_correcto
# Out:
#                          frequency
# presionó botón correcto
# Incorrecto                    2590
# Correcto                      2513

# %%
#Usamos seaborn para el gráfico con colores por categoría
ax = sns.barplot(
    x=Filtro_index_boton_correcto.index,
    y=Filtro_index_boton_correcto['frequency'],
    palette=['red', 'green']
)

#Añadir etiquetas a las barras
for p in ax.patches:
    ax.text(
        p.get_x() + p.get_width()/2.,  #Posición horizontal
        p.get_height() + 1,            #Posición vertical (ajusta según altura)
        str(int(p.get_height())),      #Valor numérico sin decimales (int)
        ha="center",                   #Alineación horizontal
        va="bottom"                    #Alineación vertical
    )

plt.title('Presionó el botón correcto')
plt.xlabel('Botón presionado')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# #### Mini juego

# %%
tabla_minijuego = freq_tbl(df['mini juego'])
tabla_minijuego
# Out:
#             mini juego  frequency  percentage  cumulative_perc
# 0           Asteroides       1054    0.179710         0.179710
# 1          Restaurante        869    0.148167         0.327877
# 2            Estrellas        813    0.138619         0.466496
# 3              Gusanos        748    0.127536         0.594032
# 4   sonidos y animales        743    0.126684         0.720716
# 5   animales y colores        545    0.092924         0.813640
# 6    figuras y colores        400    0.068201         0.881841
# 7    partes del cuerpo        320    0.054561         0.936402
# 8             Despegue        196    0.033419         0.969821
# 9                 Nulo        156    0.026598         0.996419
# 10          MiniGame_0          8    0.001364         0.997783
# 11          MiniGame_3          5    0.000853         0.998636
# 12          MiniGame_2          5    0.000853         0.999488
# 13          MiniGame_1          3    0.000512         1.000000

# %%
tabla_minijuego2 = tabla_minijuego.drop(['percentage','cumulative_perc'], axis=1)
tabla_minijuego2
# Out:
#             mini juego  frequency
# 0           Asteroides       1054
# 1          Restaurante        869
# 2            Estrellas        813
# 3              Gusanos        748
# 4   sonidos y animales        743
# 5   animales y colores        545
# 6    figuras y colores        400
# 7    partes del cuerpo        320
# 8             Despegue        196
# 9                 Nulo        156
# 10          MiniGame_0          8
# 11          MiniGame_3          5
# 12          MiniGame_2          5
# 13          MiniGame_1          3

# %%
#Usamos el diferente a para "eliminar" la fila de nulos que no necesitamos
tabla_minijuego2 = tabla_minijuego2[tabla_minijuego2['mini juego'] != 'Nulo']
tabla_minijuego2
# Out:
#             mini juego  frequency
# 0           Asteroides       1054
# 1          Restaurante        869
# 2            Estrellas        813
# 3              Gusanos        748
# 4   sonidos y animales        743
# 5   animales y colores        545
# 6    figuras y colores        400
# 7    partes del cuerpo        320
# 8             Despegue        196
# 10          MiniGame_0          8
# 11          MiniGame_3          5
# 12          MiniGame_2          5
# 13          MiniGame_1          3

# %%
#Agrupamos las filas de MiniGame_0, MiniGame_1, MiniGame_2, MiniGame_3 en una sola fila llamada 'Otros'
otros_minijuego = tabla_minijuego2[tabla_minijuego2['mini juego'].isin(['MiniGame_0', 'MiniGame_1', 'MiniGame_2', 'MiniGame_3'])]['frequency'].sum()

#Filtramos las filas que no son MiniGame_0, MiniGame_1, MiniGame_2, MiniGame_3
tabla_minijuego2 = tabla_minijuego2[~tabla_minijuego2['mini juego'].isin(['MiniGame_0', 'MiniGame_1', 'MiniGame_2', 'MiniGame_3'])]

#Añadimos la nueva fila 'Otros'
tabla_minijuego2 = pd.concat([tabla_minijuego2, pd.DataFrame({'mini juego': ['Otros'], 'frequency': [otros_minijuego]})], ignore_index=True)

tabla_minijuego2
# Out:
#            mini juego  frequency
# 0          Asteroides       1054
# 1         Restaurante        869
# 2           Estrellas        813
# 3             Gusanos        748
# 4  sonidos y animales        743
# 5  animales y colores        545
# 6   figuras y colores        400
# 7   partes del cuerpo        320
# 8            Despegue        196
# 9               Otros         21

# %%
filtro_minijuego = tabla_minijuego2[tabla_minijuego2['frequency']>1]
filtro_minijuego
# Out:
#            mini juego  frequency
# 0          Asteroides       1054
# 1         Restaurante        869
# 2           Estrellas        813
# 3             Gusanos        748
# 4  sonidos y animales        743
# 5  animales y colores        545
# 6   figuras y colores        400
# 7   partes del cuerpo        320
# 8            Despegue        196
# 9               Otros         21

# %%
Filtro_index_minijuego = filtro_minijuego.set_index('mini juego')
Filtro_index_minijuego
# Out:
#                     frequency
# mini juego
# Asteroides               1054
# Restaurante               869
# Estrellas                 813
# Gusanos                   748
# sonidos y animales        743
# animales y colores        545
# figuras y colores         400
# partes del cuerpo         320
# Despegue                  196
# Otros                      21

# %%
#Realizamos grafico de pie del dataframe filtrado
Filtro_index_minijuego["frequency"].plot(kind='pie', figsize=(20,10), shadow=True, autopct="%0.1f %%")
plt.title('Mini Juego')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# #### Color presionado

# %%
tabla_color_presionado = freq_tbl(df['color presionado'])
tabla_color_presionado
# Out:
#   color presionado  frequency  percentage  cumulative_perc
# 0           violet       1361    0.232055         0.232055
# 1            green       1298    0.221313         0.453367
# 2           yellow       1233    0.210230         0.663598
# 3             blue       1182    0.201535         0.865132
# 4             Nulo        762    0.129923         0.995055
# 5              red         29    0.004945         1.000000

# %%
tabla_color_presionado2 = tabla_color_presionado.drop(['percentage','cumulative_perc'], axis=1)
tabla_color_presionado2
# Out:
#   color presionado  frequency
# 0           violet       1361
# 1            green       1298
# 2           yellow       1233
# 3             blue       1182
# 4             Nulo        762
# 5              red         29

# %%
#Usamos el diferente a para "eliminar" la fila de nulos que no necesitamos
tabla_color_presionado2 = tabla_color_presionado2[tabla_color_presionado2['color presionado'] != 'Nulo']
tabla_color_presionado2
# Out:
#   color presionado  frequency
# 0           violet       1361
# 1            green       1298
# 2           yellow       1233
# 3             blue       1182
# 5              red         29

# %%
Filtro_index_color_presionado = tabla_color_presionado2.set_index('color presionado')
Filtro_index_color_presionado
# Out:
#                   frequency
# color presionado
# violet                 1361
# green                  1298
# yellow                 1233
# blue                   1182
# red                      29

# %%
#Usamos seaborn para el gráfico con colores por categoría
ax = sns.barplot(
    x=Filtro_index_color_presionado.index,
    y=Filtro_index_color_presionado['frequency'],
    palette=['#B57EDC', '#8BC34A', '#F7DC6F', '#4A90E2', '#FF6B6B']
)

#Añadir etiquetas a las barras
for p in ax.patches:
    ax.text(
        p.get_x() + p.get_width()/2.,  #Posición horizontal
        p.get_height() + 1,            #Posición vertical (ajusta según altura)
        str(int(p.get_height())),      #Valor numérico sin decimales (int)
        ha="center",                   #Alineación horizontal
        va="bottom"                    #Alineación vertical
    )

plt.title('Color Presionado')
plt.xlabel('Color del Botón')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# #### Dificultad

# %%
tabla_dificultad = freq_tbl(df['dificultad'])
tabla_dificultad
# Out:
#    dificultad  frequency  percentage  cumulative_perc
# 0  Episodio 1       2357    0.401876         0.401876
# 1  Episodio 2       1493    0.254561         0.656436
# 2  Episodio 3       1292    0.220290         0.876726
# 3  Episodio 4        723    0.123274         1.000000

# %%
tabla_dificultad2 = tabla_dificultad.drop(['percentage','cumulative_perc'], axis=1)
tabla_dificultad2
# Out:
#    dificultad  frequency
# 0  Episodio 1       2357
# 1  Episodio 2       1493
# 2  Episodio 3       1292
# 3  Episodio 4        723

# %%
Filtro_index_dificultad = tabla_dificultad2.set_index('dificultad')
Filtro_index_dificultad
# Out:
#             frequency
# dificultad
# Episodio 1       2357
# Episodio 2       1493
# Episodio 3       1292
# Episodio 4        723

# %%
Filtro_index_dificultad.plot(kind='area', figsize=(12,6),alpha = 0.6, color='teal')
plt.title('Nivel de Dificultad')
plt.xlabel('Dificultad')
plt.xticks(rotation=45)
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# #### Juego

# %%
tabla_juego = freq_tbl(df['juego'])
tabla_juego
# Out:
#      juego  frequency  percentage  cumulative_perc
# 0    Astro       3799    0.647741         0.647741
# 1  Cadetes       2066    0.352259         1.000000

# %%
tabla_juego2 = tabla_juego.drop(['percentage','cumulative_perc'], axis=1)
tabla_juego2
# Out:
#      juego  frequency
# 0    Astro       3799
# 1  Cadetes       2066

# %%
Filtro_index_juego = tabla_juego2.set_index('juego')
Filtro_index_juego
# Out:
#          frequency
# juego
# Astro         3799
# Cadetes       2066

# %%
#Realizamos grafico de pie del dataframe filtrado
Filtro_index_juego["frequency"].plot(kind='pie', figsize=(15,6), shadow=True, autopct="%0.1f %%")
plt.title('Juego')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# #### Auto push

# %%
tabla_auto_push = freq_tbl(df['auto push'])
tabla_auto_push
# Out:
#   auto push  frequency  percentage  cumulative_perc
# 0        No       5049    0.860870         0.860870
# 1      Nulo        762    0.129923         0.990793
# 2        Si         54    0.009207         1.000000

# %%
tabla_auto_push2 = tabla_auto_push.drop(['percentage','cumulative_perc'], axis=1)
tabla_auto_push2
# Out:
#   auto push  frequency
# 0        No       5049
# 1      Nulo        762
# 2        Si         54

# %%
#Usamos el diferente a para "eliminar" la fila de nulos que no necesitamos
tabla_auto_push2 = tabla_auto_push2[tabla_auto_push2['auto push'] != 'Nulo']
tabla_auto_push2
# Out:
#   auto push  frequency
# 0        No       5049
# 2        Si         54

# %%
Filtro_index_auto_push = tabla_auto_push2.set_index('auto push')
Filtro_index_auto_push
# Out:
#            frequency
# auto push
# No              5049
# Si                54

# %%
#Usamos seaborn para el gráfico con colores por categoría
ax = sns.barplot(
    x=Filtro_index_auto_push.index,
    y=Filtro_index_auto_push['frequency'],
    palette=['red', 'green']
)

#Añadir etiquetas a las barras
for p in ax.patches:
    ax.text(
        p.get_x() + p.get_width()/2.,  #Posición horizontal
        p.get_height() + 1,            #Posición vertical (ajusta según altura)
        str(int(p.get_height())),      #Valor numérico sin decimales (int)
        ha="center",                   #Alineación horizontal
        va="bottom"                    #Alineación vertical
    )

plt.title('Se usó Auto Push')
plt.xlabel('Auto Push')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# #### Tiempo de Interacción

# %%
#Filtramos las filas donde ninguna columna tenga el valor 999 ya que son nuestros valores nulos
df_tiempo_interaccion = df[df['tiempo de interacción'] != 999]

#Calculamos el numero total de la población "n"
df_tiempo_interaccion['tiempo de interacción'].info()
n=len(df_tiempo_interaccion) #número de entradas
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5103 entries, 0 to 5861
# Series name: tiempo de interacción
# Non-Null Count  Dtype
# --------------  -----
# 5103 non-null   float64
# dtypes: float64(1)
# memory usage: 79.7 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=df_tiempo_interaccion['tiempo de interacción'].max()
Min=df_tiempo_interaccion['tiempo de interacción'].min()
Limites= [Min, Max]
Limites
# Out:
# [0.0, 165.1935]

# %%
#Calculamos el rango R
R=Max-Min
R
# Out:
# 165.1935

# %%
#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
ni
# Out:
# 13.30998088686301

# %%
#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# 12.411249978806993

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
intervalos = np.linspace(Min, Max, num=15) #minimo, maximo, numero de clases + 1 (las calses son los intervalos)
intervalos
# Out:
# array([  0.        ,  11.79953571,  23.59907143,  35.39860714,
#         47.19814286,  58.99767857,  70.79721429,  82.59675   ,
#         94.39628571, 106.19582143, 117.99535714, 129.79489286,
#        141.59442857, 153.39396429, 165.1935    ])

# %%
# Crear categorías (ajusta las etiquetas según intervalos)
categorias = [f"{intervalos[i]:.2f} - {intervalos[i+1]:.2f}" 
    for i in range(len(intervalos)-1)] #-1 para ajustar índices
categorias
# Out:
# ['0.00 - 11.80',
#  '11.80 - 23.60',
#  '23.60 - 35.40',
#  '35.40 - 47.20',
#  '47.20 - 59.00',
#  '59.00 - 70.80',
#  '70.80 - 82.60',
#  '82.60 - 94.40',
#  '94.40 - 106.20',
#  '106.20 - 118.00',
#  '118.00 - 129.79',
#  '129.79 - 141.59',
#  '141.59 - 153.39',
#  '153.39 - 165.19']

# %%
#Finalmente creamos las categorías en la columna numérica
#Usamos el include_lowest para evitar que se eliminen datos
df_tiempo_interaccion['tiempo de interacción']=pd.cut(x= df_tiempo_interaccion['tiempo de interacción'], bins=intervalos, labels= categorias, include_lowest=True )
df_tiempo_interaccion['tiempo de interacción']
# Out:
# /var/folders/6g/_xkwmvhx4_sg_spcn348_2wc0000gn/T/ipykernel_4112/628422449.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tiempo_interaccion['tiempo de interacción']=pd.cut(x= df_tiempo_interaccion['tiempo de interacción'], bins=intervalos, labels= categorias, include_lowest=True )
# 0       0.00 - 11.80
# 1       0.00 - 11.80
# 2       0.00 - 11.80
# 3       0.00 - 11.80
# 4       0.00 - 11.80
#             ...
# 5854    0.00 - 11.80
# 5855    0.00 - 11.80
# 5856    0.00 - 11.80
# 5857    0.00 - 11.80
# 5861    0.00 - 11.80
# Name: tiempo de interacción, Length: 5103, dtype: category
# Categories (14, object): ['0.00 - 11.80' < '11.80 - 23.60' < '23.60 - 35.40' < '35.40 - 47.20' ... '118.00 - 129.79' < '129.79 - 141.59' < '141.59 - 153.39' < '153.39 - 165.19']

# %%
tabla_tiempo_interaccion = freq_tbl(df_tiempo_interaccion['tiempo de interacción'])
tabla_tiempo_interaccion
# Out:
#    tiempo de interacción  frequency  percentage  cumulative_perc
# 0           0.00 - 11.80       3881    0.760533         0.760533
# 1          11.80 - 23.60        604    0.118362         0.878895
# 2          23.60 - 35.40        274    0.053694         0.932589
# 3          35.40 - 47.20        168    0.032922         0.965510
# 4          47.20 - 59.00         66    0.012934         0.978444
# 5          82.60 - 94.40         36    0.007055         0.985499
# 6          59.00 - 70.80         33    0.006467         0.991966
# 7          70.80 - 82.60         32    0.006271         0.998236
# 8        106.20 - 118.00          5    0.000980         0.999216
# 9         94.40 - 106.20          3    0.000588         0.999804
# 10       153.39 - 165.19          1    0.000196         1.000000
# 11       118.00 - 129.79          0    0.000000         1.000000
# 12       129.79 - 141.59          0    0.000000         1.000000
# 13       141.59 - 153.39          0    0.000000         1.000000

# %%
tabla_tiempo_interaccion2 = tabla_tiempo_interaccion.drop(['percentage','cumulative_perc'], axis=1)
tabla_tiempo_interaccion2
# Out:
#    tiempo de interacción  frequency
# 0           0.00 - 11.80       3881
# 1          11.80 - 23.60        604
# 2          23.60 - 35.40        274
# 3          35.40 - 47.20        168
# 4          47.20 - 59.00         66
# 5          82.60 - 94.40         36
# 6          59.00 - 70.80         33
# 7          70.80 - 82.60         32
# 8        106.20 - 118.00          5
# 9         94.40 - 106.20          3
# 10       153.39 - 165.19          1
# 11       118.00 - 129.79          0
# 12       129.79 - 141.59          0
# 13       141.59 - 153.39          0

# %%
filtro_tiempo_interaccion = tabla_tiempo_interaccion2[tabla_tiempo_interaccion2['frequency']>=1]
filtro_tiempo_interaccion
# Out:
#    tiempo de interacción  frequency
# 0           0.00 - 11.80       3881
# 1          11.80 - 23.60        604
# 2          23.60 - 35.40        274
# 3          35.40 - 47.20        168
# 4          47.20 - 59.00         66
# 5          82.60 - 94.40         36
# 6          59.00 - 70.80         33
# 7          70.80 - 82.60         32
# 8        106.20 - 118.00          5
# 9         94.40 - 106.20          3
# 10       153.39 - 165.19          1

# %%
Filtro_index_tiempo_interaccion = filtro_tiempo_interaccion.set_index('tiempo de interacción')
Filtro_index_tiempo_interaccion
# Out:
#                        frequency
# tiempo de interacción
# 0.00 - 11.80                3881
# 11.80 - 23.60                604
# 23.60 - 35.40                274
# 35.40 - 47.20                168
# 47.20 - 59.00                 66
# 82.60 - 94.40                 36
# 59.00 - 70.80                 33
# 70.80 - 82.60                 32
# 106.20 - 118.00                5
# 94.40 - 106.20                 3
# 153.39 - 165.19                1

# %%
#Convertir el índice a categoría con orden explícito
Filtro_index_tiempo_interaccion.index = pd.Categorical(
    Filtro_index_tiempo_interaccion.index, #Datos a convertir
    categories=categorias, #Definir el orden numérico de los intervalos, es nuestra lista de categorias
    ordered=True
)

#Ordenar el DataFrame según el índice categórico
Filtro_index_tiempo_interaccion = Filtro_index_tiempo_interaccion.sort_index()

#Crear el gráfico
Filtro_index_tiempo_interaccion.plot(kind='area', figsize=(20, 10), alpha=0.6, color='teal')

#Asegurar de que todas las categorías aparezcan en el eje X
plt.xticks(
    ticks=range(len(Filtro_index_tiempo_interaccion.index)), #Posiciones
    labels=Filtro_index_tiempo_interaccion.index, #Etiquetas
    rotation=45, #Rotación para legibilidad
)

plt.title('Distribución del tiempo de interacción')
plt.xlabel('Intervalos de Tiempo')
plt.ylabel('Frecuencia')
plt.tight_layout()
plt.show()

# %%
#Comparar suma de frecuencias con el total de entradas
#Lo uso para verificar que se están usando todas las entradas en los intervalos
print(df_tiempo_interaccion.shape[0])  #Total de entradas
print(tabla_tiempo_interaccion['frequency'].sum())  #Suma de frecuencias
# Out:
# 5103
# 5103

# %% [markdown]
# #### Número de Interacción por Lección

# %%
#Filtramos las filas donde ninguna columna tenga el valor 0 ya que son nuestros valores nulos
df_numero_interaccion = df[df['número de interacción por lección'] != 0]

#Calculamos el numero total de la población "n"
df_numero_interaccion['número de interacción por lección'].info()
n=len(df_numero_interaccion) #número de entradas
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5103 entries, 0 to 5861
# Series name: número de interacción por lección
# Non-Null Count  Dtype
# --------------  -----
# 5103 non-null   float64
# dtypes: float64(1)
# memory usage: 79.7 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=df_numero_interaccion['número de interacción por lección'].max()
Min=df_numero_interaccion['número de interacción por lección'].min()
Limites= [Min, Max]
Limites
# Out:
# [1.0, 256.0]

# %%
#Calculamos el rango R
R=Max-Min
R
# Out:
# 255.0

# %%
#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
ni
# Out:
# 13.30998088686301

# %%
#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# 19.158554934641998

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
intervalos = np.linspace(Min, Max, num=21)#minimo, maximo, numero de clases + 1 (las calses son los intervalos)
intervalos
# Out:
# array([  1.  ,  13.75,  26.5 ,  39.25,  52.  ,  64.75,  77.5 ,  90.25,
#        103.  , 115.75, 128.5 , 141.25, 154.  , 166.75, 179.5 , 192.25,
#        205.  , 217.75, 230.5 , 243.25, 256.  ])

# %%
# Crear categorías (ajusta las etiquetas según intervalos)
categorias = [f"{intervalos[i]:.0f} - {intervalos[i+1]:.0f}" 
    for i in range(len(intervalos)-1)] #-1 para ajustar índices
categorias
# Out:
# ['1 - 14',
#  '14 - 26',
#  '26 - 39',
#  '39 - 52',
#  '52 - 65',
#  '65 - 78',
#  '78 - 90',
#  '90 - 103',
#  '103 - 116',
#  '116 - 128',
#  '128 - 141',
#  '141 - 154',
#  '154 - 167',
#  '167 - 180',
#  '180 - 192',
#  '192 - 205',
#  '205 - 218',
#  '218 - 230',
#  '230 - 243',
#  '243 - 256']

# %%
#Finalmente creamos las categorías en la columna numérica
#Usamos el include_lowest para evitar que se eliminen datos
df_numero_interaccion['número de interacción por lección']=pd.cut(x= df_numero_interaccion['número de interacción por lección'], bins=intervalos, labels= categorias, include_lowest=True )
df_numero_interaccion['número de interacción por lección']
# Out:
# /var/folders/6g/_xkwmvhx4_sg_spcn348_2wc0000gn/T/ipykernel_4112/503919305.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_numero_interaccion['número de interacción por lección']=pd.cut(x= df_numero_interaccion['número de interacción por lección'], bins=intervalos, labels= categorias, include_lowest=True )
# 0       1 - 14
# 1       1 - 14
# 2       1 - 14
# 3       1 - 14
# 4       1 - 14
#          ...
# 5854    1 - 14
# 5855    1 - 14
# 5856    1 - 14
# 5857    1 - 14
# 5861    1 - 14
# Name: número de interacción por lección, Length: 5103, dtype: category
# Categories (20, object): ['1 - 14' < '14 - 26' < '26 - 39' < '39 - 52' ... '205 - 218' < '218 - 230' < '230 - 243' < '243 - 256']

# %%
tabla_numero_interaccion = freq_tbl(df_numero_interaccion['número de interacción por lección'])
tabla_numero_interaccion
# Out:
#    número de interacción por lección  frequency  percentage  cumulative_perc
# 0                             1 - 14       4174    0.817950         0.817950
# 1                            14 - 26        521    0.102097         0.920047
# 2                            26 - 39        167    0.032726         0.952773
# 3                            39 - 52         37    0.007251         0.960024
# 4                          230 - 243         13    0.002548         0.962571
# 5                          218 - 230         13    0.002548         0.965119
# 6                          192 - 205         13    0.002548         0.967666
# 7                          180 - 192         13    0.002548         0.970214
# 8                          167 - 180         13    0.002548         0.972761
# 9                          141 - 154         13    0.002548         0.975309
# 10                         128 - 141         13    0.002548         0.977856
# 11                         116 - 128         13    0.002548         0.980404
# 12                          90 - 103         13    0.002548         0.982951
# 13                           78 - 90         13    0.002548         0.985499
# 14                           65 - 78         13    0.002548         0.988046
# 15                         243 - 256         13    0.002548         0.990594
# 16                         154 - 167         12    0.002352         0.992945
# 17                         103 - 116         12    0.002352         0.995297
# 18                         205 - 218         12    0.002352         0.997648
# 19                           52 - 65         12    0.002352         1.000000

# %%
tabla_numero_interaccion2 = tabla_numero_interaccion.drop(['percentage','cumulative_perc'], axis=1)
tabla_numero_interaccion2
# Out:
#    número de interacción por lección  frequency
# 0                             1 - 14       4174
# 1                            14 - 26        521
# 2                            26 - 39        167
# 3                            39 - 52         37
# 4                          230 - 243         13
# 5                          218 - 230         13
# 6                          192 - 205         13
# 7                          180 - 192         13
# 8                          167 - 180         13
# 9                          141 - 154         13
# 10                         128 - 141         13
# 11                         116 - 128         13
# 12                          90 - 103         13
# 13                           78 - 90         13
# 14                           65 - 78         13
# 15                         243 - 256         13
# 16                         154 - 167         12
# 17                         103 - 116         12
# 18                         205 - 218         12
# 19                           52 - 65         12

# %%
filtro_numero_interaccion = tabla_numero_interaccion2[tabla_numero_interaccion2['frequency']>=1]
filtro_numero_interaccion
# Out:
#    número de interacción por lección  frequency
# 0                             1 - 14       4174
# 1                            14 - 26        521
# 2                            26 - 39        167
# 3                            39 - 52         37
# 4                          230 - 243         13
# 5                          218 - 230         13
# 6                          192 - 205         13
# 7                          180 - 192         13
# 8                          167 - 180         13
# 9                          141 - 154         13
# 10                         128 - 141         13
# 11                         116 - 128         13
# 12                          90 - 103         13
# 13                           78 - 90         13
# 14                           65 - 78         13
# 15                         243 - 256         13
# 16                         154 - 167         12
# 17                         103 - 116         12
# 18                         205 - 218         12
# 19                           52 - 65         12

# %%
Filtro_index_numero_interaccion = filtro_numero_interaccion.set_index('número de interacción por lección')
Filtro_index_numero_interaccion
# Out:
#                                    frequency
# número de interacción por lección
# 1 - 14                                  4174
# 14 - 26                                  521
# 26 - 39                                  167
# 39 - 52                                   37
# 230 - 243                                 13
# 218 - 230                                 13
# 192 - 205                                 13
# 180 - 192                                 13
# 167 - 180                                 13
# 141 - 154                                 13
# 128 - 141                                 13
# 116 - 128                                 13
# 90 - 103                                  13
# 78 - 90                                   13
# 65 - 78                                   13
# 243 - 256                                 13
# 154 - 167                                 12
# 103 - 116                                 12
# 205 - 218                                 12
# 52 - 65                                   12

# %%
#Convertir el índice a categoría con orden explícito
Filtro_index_numero_interaccion.index = pd.Categorical(
    Filtro_index_numero_interaccion.index, #Datos a convertir
    categories=categorias, #Definir el orden numérico de los intervalos, es nuestra lista de categorias
    ordered=True
)

#Ordenar el DataFrame según el índice categórico
Filtro_index_numero_interaccion = Filtro_index_numero_interaccion.sort_index()

#Crear el gráfico
Filtro_index_numero_interaccion.plot(kind='area', figsize=(20, 10), alpha=0.6, color='teal')

#Asegurar de que todas las categorías aparezcan en el eje X
plt.xticks(
    ticks=range(len(Filtro_index_numero_interaccion.index)), #Posiciones
    labels=Filtro_index_numero_interaccion.index, #Etiquetas
    rotation=45, #Rotación para legibilidad
)

plt.title('Distribución del número de interacciones por lección')
plt.xlabel('Intervalos de Número de Interacciones')
plt.ylabel('Frecuencia')
plt.tight_layout()
plt.show()

# %%
#Agrupamos las filas deseadas en una sola fila llamada 'Otros'
otros_numero_interaccion = tabla_numero_interaccion2[tabla_numero_interaccion2['número de interacción por lección'].isin(['230 - 243', '218 - 230', '192 - 205', '180 - 192', '167 - 180', '141 - 154', '128 - 141', '116 - 128', '90 - 103', '78 - 90', '65 - 78', '243 - 256', '154 - 167', '103 - 116', '205 - 218', '52 - 65', '39 - 52'])]['frequency'].sum()

#Filtramos las filas que no son las que irán en otros
tabla_numero_interaccion2 = tabla_numero_interaccion2[~tabla_numero_interaccion2['número de interacción por lección'].isin(['230 - 243', '218 - 230', '192 - 205', '180 - 192', '167 - 180', '141 - 154', '128 - 141', '116 - 128', '90 - 103', '78 - 90', '65 - 78', '243 - 256', '154 - 167', '103 - 116', '205 - 218', '52 - 65', '39 - 52'])]

#Añadimos la nueva fila 'Otros'
tabla_numero_interaccion2 = pd.concat([tabla_numero_interaccion2, pd.DataFrame({'número de interacción por lección': ['Otros'], 'frequency': [otros_numero_interaccion]})], ignore_index=True)

tabla_numero_interaccion2
# Out:
#   número de interacción por lección  frequency
# 0                            1 - 14       4174
# 1                           14 - 26        521
# 2                           26 - 39        167
# 3                             Otros        241

# %%
filtro_numero_interaccion = tabla_numero_interaccion2[tabla_numero_interaccion2['frequency']>=1]
filtro_numero_interaccion
# Out:
#   número de interacción por lección  frequency
# 0                            1 - 14       4174
# 1                           14 - 26        521
# 2                           26 - 39        167
# 3                             Otros        241

# %%
Filtro_index_numero_interaccion = filtro_numero_interaccion.set_index('número de interacción por lección')
Filtro_index_numero_interaccion
# Out:
#                                    frequency
# número de interacción por lección
# 1 - 14                                  4174
# 14 - 26                                  521
# 26 - 39                                  167
# Otros                                    241

# %%
#Realizamos grafico de pie del dataframe filtrado
Filtro_index_numero_interaccion["frequency"].plot(kind='pie', figsize=(15,6), shadow=True, autopct="%0.1f %%")
plt.title('Número de interacciones por lección')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# #### Tiempo de Lección

# %%
#Filtramos las filas donde ninguna columna tenga el valor 999 ya que son nuestros valores nulos
df_tiempo_leccion = df[df['tiempo de lección'] != 999]

#Calculamos el numero total de la población "n"
df_tiempo_leccion['tiempo de lección'].info()
n=len(df_tiempo_leccion) #número de entradas
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5688 entries, 0 to 5862
# Series name: tiempo de lección
# Non-Null Count  Dtype
# --------------  -----
# 5688 non-null   float64
# dtypes: float64(1)
# memory usage: 88.9 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=df_tiempo_leccion['tiempo de lección'].max()
Min=df_tiempo_interaccion['tiempo de lección'].min()
Limites= [Min, Max]
Limites
# Out:
# [0.0, 781.3312]

# %%
#Calculamos el rango R
R=Max-Min
R
# Out:
# 781.3312

# %%
#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
ni
# Out:
# 13.466465831236077

# %%
#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# 58.02050885449595

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
intervalos = np.linspace(Min, Max, num=37)#minimo, maximo, numero de clases + 1 (las calses son los intervalos)
intervalos
# Out:
# array([  0.        ,  21.70364444,  43.40728889,  65.11093333,
#         86.81457778, 108.51822222, 130.22186667, 151.92551111,
#        173.62915556, 195.3328    , 217.03644444, 238.74008889,
#        260.44373333, 282.14737778, 303.85102222, 325.55466667,
#        347.25831111, 368.96195556, 390.6656    , 412.36924444,
#        434.07288889, 455.77653333, 477.48017778, 499.18382222,
#        520.88746667, 542.59111111, 564.29475556, 585.9984    ,
#        607.70204444, 629.40568889, 651.10933333, 672.81297778,
#        694.51662222, 716.22026667, 737.92391111, 759.62755556,
#        781.3312    ])

# %%
# Crear categorías (ajusta las etiquetas según intervalos)
categorias = [f"{intervalos[i]:.0f} - {intervalos[i+1]:.0f}" 
    for i in range(len(intervalos)-1)] #-1 para ajustar índices
categorias
# Out:
# ['0 - 22',
#  '22 - 43',
#  '43 - 65',
#  '65 - 87',
#  '87 - 109',
#  '109 - 130',
#  '130 - 152',
#  '152 - 174',
#  '174 - 195',
#  '195 - 217',
#  '217 - 239',
#  '239 - 260',
#  '260 - 282',
#  '282 - 304',
#  '304 - 326',
#  '326 - 347',
#  '347 - 369',
#  '369 - 391',
#  '391 - 412',
#  '412 - 434',
#  '434 - 456',
#  '456 - 477',
#  '477 - 499',
#  '499 - 521',
#  '521 - 543',
#  '543 - 564',
#  '564 - 586',
#  '586 - 608',
#  '608 - 629',
#  '629 - 651',
#  '651 - 673',
#  '673 - 695',
#  '695 - 716',
#  '716 - 738',
#  '738 - 760',
#  '760 - 781']

# %%
#Finalmente creamos las categorías en la columna numérica
#Usamos el include_lowest para evitar que se eliminen datos
df_tiempo_leccion['tiempo de lección']=pd.cut(x= df_tiempo_leccion['tiempo de lección'], bins=intervalos, labels= categorias, include_lowest=True )
df_tiempo_leccion['tiempo de lección']
# Out:
# /var/folders/6g/_xkwmvhx4_sg_spcn348_2wc0000gn/T/ipykernel_4112/3142458860.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tiempo_leccion['tiempo de lección']=pd.cut(x= df_tiempo_leccion['tiempo de lección'], bins=intervalos, labels= categorias, include_lowest=True )
# 0        0 - 22
# 1        0 - 22
# 2        0 - 22
# 3        0 - 22
# 4        0 - 22
#          ...
# 5857     0 - 22
# 5858    43 - 65
# 5859     0 - 22
# 5861     0 - 22
# 5862     0 - 22
# Name: tiempo de lección, Length: 5688, dtype: category
# Categories (36, object): ['0 - 22' < '22 - 43' < '43 - 65' < '65 - 87' ... '695 - 716' < '716 - 738' < '738 - 760' < '760 - 781']

# %%
tabla_tiempo_leccion = freq_tbl(df_tiempo_leccion['tiempo de lección'])
tabla_tiempo_leccion
# Out:
#    tiempo de lección  frequency  percentage  cumulative_perc
# 0             0 - 22       5217    0.917194         0.917194
# 1            22 - 43        167    0.029360         0.946554
# 2            43 - 65        105    0.018460         0.965014
# 3            65 - 87         74    0.013010         0.978024
# 4           87 - 109         47    0.008263         0.986287
# 5          109 - 130         29    0.005098         0.991385
# 6          130 - 152         17    0.002989         0.994374
# 7          152 - 174          8    0.001406         0.995781
# 8          174 - 195          7    0.001231         0.997011
# 9          195 - 217          5    0.000879         0.997890
# 10         217 - 239          4    0.000703         0.998594
# 11         239 - 260          4    0.000703         0.999297
# 12         260 - 282          2    0.000352         0.999648
# 13         304 - 326          1    0.000176         0.999824
# 14         760 - 781          1    0.000176         1.000000
# 15         326 - 347          0    0.000000         1.000000
# 16         564 - 586          0    0.000000         1.000000
# 17         738 - 760          0    0.000000         1.000000
# 18         716 - 738          0    0.000000         1.000000
# 19         695 - 716          0    0.000000         1.000000
# 20         673 - 695          0    0.000000         1.000000
# 21         651 - 673          0    0.000000         1.000000
# 22         629 - 651          0    0.000000         1.000000
# 23         608 - 629          0    0.000000         1.000000
# 24         586 - 608          0    0.000000         1.000000
# 25         543 - 564          0    0.000000         1.000000
# 26         347 - 369          0    0.000000         1.000000
# 27         521 - 543          0    0.000000         1.000000
# 28         499 - 521          0    0.000000         1.000000
# 29         477 - 499          0    0.000000         1.000000
# 30         456 - 477          0    0.000000         1.000000
# 31         434 - 456          0    0.000000         1.000000
# 32         412 - 434          0    0.000000         1.000000
# 33         282 - 304          0    0.000000         1.000000
# 34         369 - 391          0    0.000000         1.000000
# 35         391 - 412          0    0.000000         1.000000

# %%
tabla_tiempo_leccion2 = tabla_tiempo_leccion.drop(['percentage','cumulative_perc'], axis=1)
tabla_tiempo_leccion2
# Out:
#    tiempo de lección  frequency
# 0             0 - 22       5217
# 1            22 - 43        167
# 2            43 - 65        105
# 3            65 - 87         74
# 4           87 - 109         47
# 5          109 - 130         29
# 6          130 - 152         17
# 7          152 - 174          8
# 8          174 - 195          7
# 9          195 - 217          5
# 10         217 - 239          4
# 11         239 - 260          4
# 12         260 - 282          2
# 13         304 - 326          1
# 14         760 - 781          1
# 15         326 - 347          0
# 16         564 - 586          0
# 17         738 - 760          0
# 18         716 - 738          0
# 19         695 - 716          0
# 20         673 - 695          0
# 21         651 - 673          0
# 22         629 - 651          0
# 23         608 - 629          0
# 24         586 - 608          0
# 25         543 - 564          0
# 26         347 - 369          0
# 27         521 - 543          0
# 28         499 - 521          0
# 29         477 - 499          0
# 30         456 - 477          0
# 31         434 - 456          0
# 32         412 - 434          0
# 33         282 - 304          0
# 34         369 - 391          0
# 35         391 - 412          0

# %%
filtro_tiempo_leccion = tabla_tiempo_leccion2[tabla_tiempo_leccion2['frequency']>=1]
filtro_tiempo_leccion
# Out:
#    tiempo de lección  frequency
# 0             0 - 22       5217
# 1            22 - 43        167
# 2            43 - 65        105
# 3            65 - 87         74
# 4           87 - 109         47
# 5          109 - 130         29
# 6          130 - 152         17
# 7          152 - 174          8
# 8          174 - 195          7
# 9          195 - 217          5
# 10         217 - 239          4
# 11         239 - 260          4
# 12         260 - 282          2
# 13         304 - 326          1
# 14         760 - 781          1

# %%
Filtro_index_tiempo_leccion = filtro_tiempo_leccion.set_index('tiempo de lección')
Filtro_index_tiempo_leccion
# Out:
#                    frequency
# tiempo de lección
# 0 - 22                  5217
# 22 - 43                  167
# 43 - 65                  105
# 65 - 87                   74
# 87 - 109                  47
# 109 - 130                 29
# 130 - 152                 17
# 152 - 174                  8
# 174 - 195                  7
# 195 - 217                  5
# 217 - 239                  4
# 239 - 260                  4
# 260 - 282                  2
# 304 - 326                  1
# 760 - 781                  1

# %%
#Convertir el índice a categoría con orden explícito
Filtro_index_tiempo_leccion.index = pd.Categorical(
    Filtro_index_tiempo_leccion.index, #Datos a convertir
    categories=categorias, #Definir el orden numérico de los intervalos, es nuestra lista de categorias
    ordered=True
)

#Ordenar el DataFrame según el índice categórico
Filtro_index_tiempo_leccion = Filtro_index_tiempo_leccion.sort_index()

#Crear el gráfico
Filtro_index_tiempo_leccion.plot(kind='area', figsize=(20, 10), alpha=0.6, color='teal')

#Asegurar de que todas las categorías aparezcan en el eje X
plt.xticks(
    ticks=range(len(Filtro_index_tiempo_leccion.index)), #Posiciones
    labels=Filtro_index_tiempo_leccion.index, #Etiquetas
    rotation=45, #Rotación para legibilidad
)

plt.title('Distribución del tiempo por lección')
plt.xlabel('Intervalos de tiempo')
plt.ylabel('Frecuencia')
plt.tight_layout()
plt.show()

# %%
#Agrupamos las filas deseadas en una sola fila llamada 'Otros'
otros_tiempo_leccion = tabla_tiempo_leccion2[tabla_tiempo_leccion2['tiempo de lección'].isin(['760 - 781', '304 - 326', '260 - 282', '239 - 260', '217 - 239', '195 - 217', '217 - 239', '195 - 217', '174 - 195', '152 - 174', '130 - 152', '109 - 130'])]['frequency'].sum()

#Filtramos las filas que no son las que irán en otros
tabla_tiempo_leccion2 = tabla_tiempo_leccion2[~tabla_tiempo_leccion2['tiempo de lección'].isin(['760 - 781', '304 - 326', '260 - 282', '239 - 260', '217 - 239', '195 - 217', '217 - 239', '195 - 217', '174 - 195', '152 - 174', '130 - 152', '109 - 130'])]

#Añadimos la nueva fila 'Otros'
tabla_tiempo_leccion2 = pd.concat([tabla_tiempo_leccion2, pd.DataFrame({'tiempo de lección': ['Otros'], 'frequency': [otros_tiempo_leccion]})], ignore_index=True)

tabla_tiempo_leccion2
# Out:
#    tiempo de lección  frequency
# 0             0 - 22       5217
# 1            22 - 43        167
# 2            43 - 65        105
# 3            65 - 87         74
# 4           87 - 109         47
# 5          326 - 347          0
# 6          564 - 586          0
# 7          738 - 760          0
# 8          716 - 738          0
# 9          695 - 716          0
# 10         673 - 695          0
# 11         651 - 673          0
# 12         629 - 651          0
# 13         608 - 629          0
# 14         586 - 608          0
# 15         543 - 564          0
# 16         347 - 369          0
# 17         521 - 543          0
# 18         499 - 521          0
# 19         477 - 499          0
# 20         456 - 477          0
# 21         434 - 456          0
# 22         412 - 434          0
# 23         282 - 304          0
# 24         369 - 391          0
# 25         391 - 412          0
# 26             Otros         78

# %%
filtro_tiempo_leccion = tabla_tiempo_leccion2[tabla_tiempo_leccion2['frequency']>=1]
filtro_tiempo_leccion
# Out:
#    tiempo de lección  frequency
# 0             0 - 22       5217
# 1            22 - 43        167
# 2            43 - 65        105
# 3            65 - 87         74
# 4           87 - 109         47
# 26             Otros         78

# %%
Filtro_index_tiempo_leccion = filtro_tiempo_leccion.set_index('tiempo de lección')
Filtro_index_tiempo_leccion
# Out:
#                    frequency
# tiempo de lección
# 0 - 22                  5217
# 22 - 43                  167
# 43 - 65                  105
# 65 - 87                   74
# 87 - 109                  47
# Otros                     78

# %%
#Realizamos grafico de pie del dataframe filtrado
Filtro_index_tiempo_leccion["frequency"].plot(kind='pie', figsize=(15,10), shadow=True, autopct="%0.1f %%")
plt.title('Tiempo por lección')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# #### Tiempo de sesión

# %%
#Filtramos las filas donde ninguna columna tenga el valor 9999 ya que son nuestros valores nulos
df_tiempo_sesion = df[df['tiempo de sesión'] != 9999]

#Calculamos el numero total de la población "n"
df_tiempo_sesion['tiempo de sesión'].info()
n=len(df_tiempo_sesion) #número de entradas
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5259 entries, 0 to 5863
# Series name: tiempo de sesión
# Non-Null Count  Dtype
# --------------  -----
# 5259 non-null   float64
# dtypes: float64(1)
# memory usage: 82.2 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=df_tiempo_sesion['tiempo de sesión'].max()
Min=df_tiempo_sesion['tiempo de sesión'].min()
Limites= [Min, Max]
Limites
# Out:
# [0.0, 2144.452]

# %%
#Calculamos el rango R
R=Max-Min
R
# Out:
# 2144.452

# %%
#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
ni
# Out:
# 13.353398527100678

# %%
#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# 160.5922264394223

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
intervalos = np.linspace(Min, Max, num=41)#minimo, maximo, numero de clases + 1 (las calses son los intervalos)
intervalos
# Out:
# array([   0.    ,   53.6113,  107.2226,  160.8339,  214.4452,  268.0565,
#         321.6678,  375.2791,  428.8904,  482.5017,  536.113 ,  589.7243,
#         643.3356,  696.9469,  750.5582,  804.1695,  857.7808,  911.3921,
#         965.0034, 1018.6147, 1072.226 , 1125.8373, 1179.4486, 1233.0599,
#        1286.6712, 1340.2825, 1393.8938, 1447.5051, 1501.1164, 1554.7277,
#        1608.339 , 1661.9503, 1715.5616, 1769.1729, 1822.7842, 1876.3955,
#        1930.0068, 1983.6181, 2037.2294, 2090.8407, 2144.452 ])

# %%
# Crear categorías (ajusta las etiquetas según intervalos)
categorias = [f"{intervalos[i]:.0f} - {intervalos[i+1]:.0f}" 
    for i in range(len(intervalos)-1)] #-1 para ajustar índices
categorias
# Out:
# ['0 - 54',
#  '54 - 107',
#  '107 - 161',
#  '161 - 214',
#  '214 - 268',
#  '268 - 322',
#  '322 - 375',
#  '375 - 429',
#  '429 - 483',
#  '483 - 536',
#  '536 - 590',
#  '590 - 643',
#  '643 - 697',
#  '697 - 751',
#  '751 - 804',
#  '804 - 858',
#  '858 - 911',
#  '911 - 965',
#  '965 - 1019',
#  '1019 - 1072',
#  '1072 - 1126',
#  '1126 - 1179',
#  '1179 - 1233',
#  '1233 - 1287',
#  '1287 - 1340',
#  '1340 - 1394',
#  '1394 - 1448',
#  '1448 - 1501',
#  '1501 - 1555',
#  '1555 - 1608',
#  '1608 - 1662',
#  '1662 - 1716',
#  '1716 - 1769',
#  '1769 - 1823',
#  '1823 - 1876',
#  '1876 - 1930',
#  '1930 - 1984',
#  '1984 - 2037',
#  '2037 - 2091',
#  '2091 - 2144']

# %%
#Finalmente creamos las categorías en la columna numérica
#Usamos el include_lowest para evitar que se eliminen datos
df_tiempo_sesion['tiempo de sesión']=pd.cut(x= df_tiempo_sesion['tiempo de sesión'], bins=intervalos, labels= categorias, include_lowest=True )
df_tiempo_sesion['tiempo de sesión']
# Out:
# /var/folders/6g/_xkwmvhx4_sg_spcn348_2wc0000gn/T/ipykernel_4112/932227275.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tiempo_sesion['tiempo de sesión']=pd.cut(x= df_tiempo_sesion['tiempo de sesión'], bins=intervalos, labels= categorias, include_lowest=True )
# 0          0 - 54
# 1          0 - 54
# 2          0 - 54
# 3          0 - 54
# 4          0 - 54
#           ...
# 5856       0 - 54
# 5857       0 - 54
# 5860    322 - 375
# 5861       0 - 54
# 5863       0 - 54
# Name: tiempo de sesión, Length: 5259, dtype: category
# Categories (40, object): ['0 - 54' < '54 - 107' < '107 - 161' < '161 - 214' ... '1930 - 1984' < '1984 - 2037' < '2037 - 2091' < '2091 - 2144']

# %%
tabla_tiempo_sesion = freq_tbl(df_tiempo_sesion['tiempo de sesión'])
tabla_tiempo_sesion
# Out:
#    tiempo de sesión  frequency  percentage  cumulative_perc
# 0            0 - 54       5113    0.972238         0.972238
# 1          54 - 107         40    0.007606         0.979844
# 2         107 - 161         19    0.003613         0.983457
# 3         214 - 268         11    0.002092         0.985549
# 4         268 - 322         11    0.002092         0.987640
# 5         161 - 214          9    0.001711         0.989352
# 6         322 - 375          9    0.001711         0.991063
# 7         429 - 483          4    0.000761         0.991824
# 8       1072 - 1126          4    0.000761         0.992584
# 9         375 - 429          4    0.000761         0.993345
# 10      1287 - 1340          3    0.000570         0.993915
# 11        697 - 751          3    0.000570         0.994486
# 12      1179 - 1233          3    0.000570         0.995056
# 13        536 - 590          3    0.000570         0.995627
# 14      1340 - 1394          2    0.000380         0.996007
# 15        804 - 858          2    0.000380         0.996387
# 16        858 - 911          2    0.000380         0.996767
# 17      1394 - 1448          2    0.000380         0.997148
# 18      1233 - 1287          2    0.000380         0.997528
# 19      1984 - 2037          1    0.000190         0.997718
# 20      1930 - 1984          1    0.000190         0.997908
# 21      1769 - 1823          1    0.000190         0.998098
# 22      1662 - 1716          1    0.000190         0.998289
# 23      1555 - 1608          1    0.000190         0.998479
# 24      1448 - 1501          1    0.000190         0.998669
# 25        483 - 536          1    0.000190         0.998859
# 26      1126 - 1179          1    0.000190         0.999049
# 27      1019 - 1072          1    0.000190         0.999239
# 28       965 - 1019          1    0.000190         0.999430
# 29        911 - 965          1    0.000190         0.999620
# 30        751 - 804          1    0.000190         0.999810
# 31      2091 - 2144          1    0.000190         1.000000
# 32      1501 - 1555          0    0.000000         1.000000
# 33      1608 - 1662          0    0.000000         1.000000
# 34      1716 - 1769          0    0.000000         1.000000
# 35      1823 - 1876          0    0.000000         1.000000
# 36      1876 - 1930          0    0.000000         1.000000
# 37        643 - 697          0    0.000000         1.000000
# 38        590 - 643          0    0.000000         1.000000
# 39      2037 - 2091          0    0.000000         1.000000

# %%
tabla_tiempo_sesion2 = tabla_tiempo_sesion.drop(['percentage','cumulative_perc'], axis=1)
tabla_tiempo_sesion2
# Out:
#    tiempo de sesión  frequency
# 0            0 - 54       5113
# 1          54 - 107         40
# 2         107 - 161         19
# 3         214 - 268         11
# 4         268 - 322         11
# 5         161 - 214          9
# 6         322 - 375          9
# 7         429 - 483          4
# 8       1072 - 1126          4
# 9         375 - 429          4
# 10      1287 - 1340          3
# 11        697 - 751          3
# 12      1179 - 1233          3
# 13        536 - 590          3
# 14      1340 - 1394          2
# 15        804 - 858          2
# 16        858 - 911          2
# 17      1394 - 1448          2
# 18      1233 - 1287          2
# 19      1984 - 2037          1
# 20      1930 - 1984          1
# 21      1769 - 1823          1
# 22      1662 - 1716          1
# 23      1555 - 1608          1
# 24      1448 - 1501          1
# 25        483 - 536          1
# 26      1126 - 1179          1
# 27      1019 - 1072          1
# 28       965 - 1019          1
# 29        911 - 965          1
# 30        751 - 804          1
# 31      2091 - 2144          1
# 32      1501 - 1555          0
# 33      1608 - 1662          0
# 34      1716 - 1769          0
# 35      1823 - 1876          0
# 36      1876 - 1930          0
# 37        643 - 697          0
# 38        590 - 643          0
# 39      2037 - 2091          0

# %%
filtro_tiempo_sesion = tabla_tiempo_sesion2[tabla_tiempo_sesion2['frequency']>=1]
filtro_tiempo_sesion
# Out:
#    tiempo de sesión  frequency
# 0            0 - 54       5113
# 1          54 - 107         40
# 2         107 - 161         19
# 3         214 - 268         11
# 4         268 - 322         11
# 5         161 - 214          9
# 6         322 - 375          9
# 7         429 - 483          4
# 8       1072 - 1126          4
# 9         375 - 429          4
# 10      1287 - 1340          3
# 11        697 - 751          3
# 12      1179 - 1233          3
# 13        536 - 590          3
# 14      1340 - 1394          2
# 15        804 - 858          2
# 16        858 - 911          2
# 17      1394 - 1448          2
# 18      1233 - 1287          2
# 19      1984 - 2037          1
# 20      1930 - 1984          1
# 21      1769 - 1823          1
# 22      1662 - 1716          1
# 23      1555 - 1608          1
# 24      1448 - 1501          1
# 25        483 - 536          1
# 26      1126 - 1179          1
# 27      1019 - 1072          1
# 28       965 - 1019          1
# 29        911 - 965          1
# 30        751 - 804          1
# 31      2091 - 2144          1

# %%
Filtro_index_tiempo_sesion = filtro_tiempo_sesion.set_index('tiempo de sesión')
Filtro_index_tiempo_sesion
# Out:
#                   frequency
# tiempo de sesión
# 0 - 54                 5113
# 54 - 107                 40
# 107 - 161                19
# 214 - 268                11
# 268 - 322                11
# 161 - 214                 9
# 322 - 375                 9
# 429 - 483                 4
# 1072 - 1126               4
# 375 - 429                 4
# 1287 - 1340               3
# 697 - 751                 3
# 1179 - 1233               3
# 536 - 590                 3
# 1340 - 1394               2
# 804 - 858                 2
# 858 - 911                 2
# 1394 - 1448               2
# 1233 - 1287               2
# 1984 - 2037               1
# 1930 - 1984               1
# 1769 - 1823               1
# 1662 - 1716               1
# 1555 - 1608               1
# 1448 - 1501               1
# 483 - 536                 1
# 1126 - 1179               1
# 1019 - 1072               1
# 965 - 1019                1
# 911 - 965                 1
# 751 - 804                 1
# 2091 - 2144               1

# %%
#Convertir el índice a categoría con orden explícito
Filtro_index_tiempo_sesion.index = pd.Categorical(
    Filtro_index_tiempo_sesion.index, #Datos a convertir
    categories=categorias, #Definir el orden numérico de los intervalos, es nuestra lista de categorias
    ordered=True
)

#Ordenar el DataFrame según el índice categórico
Filtro_index_tiempo_sesion = Filtro_index_tiempo_sesion.sort_index()

#Crear el gráfico
Filtro_index_tiempo_sesion.plot(kind='area', figsize=(20, 10), alpha=0.6, color='teal')

#Asegurar de que todas las categorías aparezcan en el eje X
plt.xticks(
    ticks=range(len(Filtro_index_tiempo_sesion.index)), #Posiciones
    labels=Filtro_index_tiempo_sesion.index, #Etiquetas
    rotation=45, #Rotación para legibilidad
)

plt.title('Distribución del tiempo por sesión')
plt.xlabel('Intervalos de tiempo')
plt.ylabel('Frecuencia')
plt.tight_layout()
plt.show()

# %%
#Agrupamos las filas deseadas en una sola fila llamada 'Otros'
otros_tiempo_sesion = tabla_tiempo_sesion2[tabla_tiempo_sesion2['tiempo de sesión'].isin(['2091 - 2144', '751 - 804', '911 - 965', '965 - 1019', '1019 - 1072', '1126 - 1179', '483 - 536', '1448 - 1501', '1555 - 1608', '1662 - 1716', '1769 - 1823', '1930 - 1984', '1984 - 2037', '1233 - 1287', '1394 - 1448', '858 - 911', '804 - 858', '1340 - 1394', '536 - 590', '1179 - 1233', '697 - 751', '1287 - 1340', '375 - 429', '1072 - 1126', '429 - 483', '322 - 375', '161 - 214', '268 - 322', '214 - 268', '107 - 161'])]['frequency'].sum()

#Filtramos las filas que no son las que irán en otros
tabla_tiempo_sesion2 = tabla_tiempo_sesion2[~tabla_tiempo_sesion2['tiempo de sesión'].isin(['2091 - 2144', '751 - 804', '911 - 965', '965 - 1019', '1019 - 1072', '1126 - 1179', '483 - 536', '1448 - 1501', '1555 - 1608', '1662 - 1716', '1769 - 1823', '1930 - 1984', '1984 - 2037', '1233 - 1287', '1394 - 1448', '858 - 911', '804 - 858', '1340 - 1394', '536 - 590', '1179 - 1233', '697 - 751', '1287 - 1340', '375 - 429', '1072 - 1126', '429 - 483', '322 - 375', '161 - 214', '268 - 322', '214 - 268', '107 - 161'])]

#Añadimos la nueva fila 'Otros'
tabla_tiempo_sesion2 = pd.concat([tabla_tiempo_sesion2, pd.DataFrame({'tiempo de sesión': ['Otros'], 'frequency': [otros_tiempo_sesion]})], ignore_index=True)

tabla_tiempo_sesion2
# Out:
#    tiempo de sesión  frequency
# 0            0 - 54       5113
# 1          54 - 107         40
# 2       1501 - 1555          0
# 3       1608 - 1662          0
# 4       1716 - 1769          0
# 5       1823 - 1876          0
# 6       1876 - 1930          0
# 7         643 - 697          0
# 8         590 - 643          0
# 9       2037 - 2091          0
# 10            Otros        106

# %%
filtro_tiempo_sesion = tabla_tiempo_sesion2[tabla_tiempo_sesion2['frequency']>=1]
filtro_tiempo_sesion
# Out:
#    tiempo de sesión  frequency
# 0            0 - 54       5113
# 1          54 - 107         40
# 10            Otros        106

# %%
Filtro_index_tiempo_sesion = filtro_tiempo_sesion.set_index('tiempo de sesión')
Filtro_index_tiempo_sesion
# Out:
#                   frequency
# tiempo de sesión
# 0 - 54                 5113
# 54 - 107                 40
# Otros                   106

# %%
#Realizamos grafico de pie del dataframe filtrado
Filtro_index_tiempo_sesion["frequency"].plot(kind='pie', figsize=(20,10), shadow=True, autopct="%0.1f %%")
plt.title('Tiempo por sesión')
plt.ylabel('Frecuencia')
plt.show()
